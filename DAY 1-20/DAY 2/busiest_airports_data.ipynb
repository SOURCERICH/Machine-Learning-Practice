# %%
import pandas as pd
df = pd.read_csv('data\List of busiest airports by passenger traffic 2018.csv').iloc[:,1:] 
df22 = pd.read_csv('data\List of busiest airports by passenger traffic 2022.csv') 

# Below are same as 2018
# df19 = pd.read_csv('data\List of busiest airports by passenger traffic 2019.csv') 
# df20 = pd.read_csv('dta\List of busiest airports by passenger traffic 2020.csv') 
# df21 = pd.read_csv('data\List of busiest airports by passenger traffic 2021.csv')

# %%
df.head()
# Out:
#    Rank                                           Airport  \
# 0   1.0  Hartsfield–Jackson Atlanta International Airport
# 1   2.0           Dallas Fort Worth International Airport
# 2   3.0                      Denver International Airport
# 3   4.0                      O'Hare International Airport
# 4   5.0                 Los Angeles International Airport
#
#                    Location        Country Code (IATA/ICAO)  Total passengers  \
# 0          Atlanta, Georgia  United States         ATL/KATL          75704760
# 1  Dallas-Fort Worth, Texas  United States         DFW/KDFW          62465756
# 2          Denver, Colorado  United States         DEN/KDEN          58828552
# 3         Chicago, Illinois  United States         ORD/KORD          54020399
# 4   Los Angeles, California  United States         LAX/KLAX          48007284
#
#   Rank change % change
# 0           1    76.4%
# 1           2    58.7%
# 2           5    74.4%
# 3           9    75.1%
# 4          10    66.8%

# %%
# import matplotlib.pyplot as plt
# plt.figure((10))
# plt.plot(df["Total passengers"],df["Country"],)

# count = 0;
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df["Total passengers"], df["Country"])
plt.xlabel("Total Passengers")
plt.ylabel("Country")
plt.title("Passengers by Country")
plt.show()


countryList = list(df["Country"])

# :
# print(df.iloc[:,2:3].count("China"))
dict_country = {i: countryList.count(i) for i in countryList }
# 
print(dict_country)

# df_new = pd.DataFrame()
# Out:
# {'United States': 20, 'China': 12, 'India': 1, 'Turkey': 3, 'Mexico': 2, 'Indonesia': 1, 'Russia': 2, 'United Arab Emirates': 1, 'France': 1, 'Japan': 1, 'South Korea': 2, 'Netherlands': 1, 'Germany': 1, 'Brazil': 1, 'Spain': 1}

# %%
'''bA = df.drop(df.columns[[0,5]], axis =1) #Busiest Airports = bA
bA['Location'] = df['Location'].astype(str) +", "+ df['Country']
bA = bA.drop(bA.columns[[3]], axis=1)
bA.head()'''
df.dtypes
#display(bA)
# Out:
# Rank                float64
# Airport              object
# Location             object
# Country              object
# Code (IATA/ICAO)     object
# Total passengers      int64
# Rank change          object
# % change             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              50 non-null     float64
#  1   Airport           50 non-null     object
#  2   Location          50 non-null     object
#  3   Country           50 non-null     object
#  4   Code (IATA/ICAO)  50 non-null     object
#  5   Total passengers  50 non-null     int64
#  6   Rank change       50 non-null     object
#  7   % change          50 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#            Rank  Total passengers
# count  50.00000      5.000000e+01
# mean   25.50000      3.305564e+07
# std    14.57738      1.120089e+07
# min     1.00000      1.998306e+07
# 25%    13.25000      2.500669e+07
# 50%    25.50000      3.086589e+07
# 75%    37.75000      3.710211e+07
# max    50.00000      7.570476e+07

# %%
list_col = df.dtypes[df.dtypes == object].index
df[list_col].describe()
# Out:
#                                                  Airport          Location  \
# count                                                 50                50
# unique                                                50                50
# top     Hartsfield–Jackson Atlanta International Airport  Atlanta, Georgia
# freq                                                   1                 1
#
#               Country Code (IATA/ICAO) Rank change % change
# count              50               50          50       50
# unique             15               50          23       50
# top     United States         ATL/KATL           9    76.4%
# freq               20                1           5        1

# %%
df.describe().T
# Out:
#                   count         mean           std         min          25%  \
# Rank               50.0        25.50  1.457738e+01         1.0        13.25
# Total passengers   50.0  33055644.98  1.120089e+07  19983064.0  25006690.00
#
#                          50%          75%         max
# Rank                    25.5        37.75        50.0
# Total passengers  30865889.0  37102108.50  75704760.0

# %%
df.isnull().sum()
# Out:
# Rank                0
# Airport             0
# Location            0
# Country             0
# Code (IATA/ICAO)    0
# Total passengers    0
# Rank change         0
# % change            0
# dtype: int64

# %%
data_cleaned = df.drop_duplicates()

# %%
data_cleaned.dropna(inplace=True)

# %%
data_cleaned.describe()
# Out:
#            Rank  Total passengers
# count  50.00000      5.000000e+01
# mean   25.50000      3.305564e+07
# std    14.57738      1.120089e+07
# min     1.00000      1.998306e+07
# 25%    13.25000      2.500669e+07
# 50%    25.50000      3.086589e+07
# 75%    37.75000      3.710211e+07
# max    50.00000      7.570476e+07

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Total passengers',data=data_cleaned)
plt.title("Top Countries by Passenger Traffic")
plt.xlabel("Country")
plt.ylabel("Total passengers")
plt.xticks(rotation=90)
plt.show()
